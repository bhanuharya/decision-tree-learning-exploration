# %%
import pandas as pd
import scipy as sp
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn import svm
import matplotlib as plt

# %%
from sklearn.datasets import load_breast_cancer

#Preparing data
breast_cancer = load_breast_cancer()
data_play_tennis  = pd.read_csv('play_tennis.csv')

#convert breast cancer data to pandas dataframe
data_breast_cancer = pd.DataFrame(breast_cancer['data'], columns=breast_cancer['feature_names'])
data_breast_cancer['target'] = breast_cancer['target']

# %%
#Breast Cancer Data Head
data_breast_cancer.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
# Play Tennis Data Head
from sklearn.preprocessing import LabelEncoder
Le = LabelEncoder()

data_play_tennis = data_play_tennis.drop(columns=['day'])
data_play_tennis['outlook'] = Le.fit_transform(data_play_tennis['outlook'])
data_play_tennis['temp'] = Le.fit_transform(data_play_tennis['temp'])
data_play_tennis['humidity'] = Le.fit_transform(data_play_tennis['humidity'])
data_play_tennis['wind'] = Le.fit_transform(data_play_tennis['wind'])
data_play_tennis['play'] = Le.fit_transform(data_play_tennis['play'])
data_play_tennis.head()
# Out:
#    outlook  temp  humidity  wind  play
# 0        2     1         0     1     0
# 1        2     1         0     0     0
# 2        0     1         0     1     1
# 3        1     2         0     1     1
# 4        1     0         1     1     1

# %%
#Split breast cancer to training and testing data
y1 = data_breast_cancer.target
x1 = data_breast_cancer.drop('target', axis = 1)

x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.2)

print("shape of original dataset :", data_breast_cancer.shape)
print("shape of input - training set", x1_train.shape)
print("shape of output - training set", y1_train.shape)
print("shape of input - testing set", x1_test.shape)
print("shape of output - testing set", y1_test.shape)
# Out:
# shape of original dataset : (569, 31)
# shape of input - training set (455, 30)
# shape of output - training set (455,)
# shape of input - testing set (114, 30)
# shape of output - testing set (114,)

# %%
#Split play tennis to training and testing data
y2 = data_play_tennis.play
x2 = data_play_tennis.drop('play', axis = 1)

x2_train,x2_test,y2_train,y2_test=train_test_split(x2,y2,test_size=0.2)

print("shape of original dataset :", data_play_tennis.shape)
print("shape of input - training set", x2_train.shape)
print("shape of output - training set", y2_train.shape)
print("shape of input - testing set", x2_test.shape)
print("shape of output - testing set", y2_test.shape)
# Out:
# shape of original dataset : (14, 5)
# shape of input - training set (11, 4)
# shape of output - training set (11,)
# shape of input - testing set (3, 4)
# shape of output - testing set (3,)

# %%
# Decision Tree Classifier - Breast Cancer
from sklearn import tree
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier, export_text

clf = tree.DecisionTreeClassifier()
clf = clf.fit(x1_train, y1_train)
y_pred_1 = clf.predict(x1_test)
print("Accuracy:",metrics.accuracy_score(y1_test, y_pred_1))
print("F1:",metrics.f1_score(y1_test, y_pred_1))

#show graph
r = export_text(clf, feature_names=x1.columns.values.tolist())
print(r)
# Out:
# Accuracy: 0.9210526315789473
# F1: 0.9440993788819876
# |--- worst area <= 874.85
# |   |--- worst concave points <= 0.16
# |   |   |--- worst concave points <= 0.13
# |   |   |   |--- area error <= 48.98
# |   |   |   |   |--- fractal dimension error <= 0.00
# |   |   |   |   |   |--- worst concave points <= 0.09
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- worst concave points >  0.09
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- fractal dimension error >  0.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- area error >  48.98
# |   |   |   |   |--- fractal dimension error <= 0.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- fractal dimension error >  0.00
# |   |   |   |   |   |--- class: 1
# |   |   |--- worst concave points >  0.13
# |   |   |   |--- worst texture <= 28.81
# |   |   |   |   |--- symmetry error <= 0.01
# |   |   |   |   |   |--- worst perimeter <= 111.40
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- worst perimeter >  111.40
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- symmetry error >  0.01
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- worst texture >  28.81
# |   |   |   |   |--- class: 0
# |   |--- worst concave points >  0.16
# |   |   |--- worst texture <= 23.47
# |   |   |   |--- class: 1
# |   |   |--- worst texture >  23.47
# |   |   |   |--- class: 0
# |--- worst area >  874.85
# |   |--- texture error <= 0.47
# |   |   |--- class: 1
# |   |--- texture error >  0.47
# |   |   |--- worst concavity <= 0.18
# |   |   |   |--- worst concavity <= 0.16
# |   |   |   |   |--- class: 0
# |   |   |   |--- worst concavity >  0.16
# |   |   |   |   |--- class: 1
# |   |   |--- worst concavity >  0.18
# |   |   |   |--- class: 0

# %%
#Decision Tree Classifier - Breast Cancer

clf = tree.DecisionTreeClassifier()
clf = clf.fit(x2_train, y2_train)
y_pred_2 = clf.predict(x2_test)
print("Accuracy:",metrics.accuracy_score(y2_test, y_pred_2))
print("F1:",metrics.f1_score(y2_test, y_pred_2))

#show graph
r = export_text(clf, feature_names=x2.columns.values.tolist())
print(r)
# Out:
# Accuracy: 0.6666666666666666
# F1: 0.6666666666666666
# |--- outlook <= 1.50
# |   |--- wind <= 0.50
# |   |   |--- outlook <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- outlook >  0.50
# |   |   |   |--- class: 0
# |   |--- wind >  0.50
# |   |   |--- class: 1
# |--- outlook >  1.50
# |   |--- temp <= 0.50
# |   |   |--- class: 1
# |   |--- temp >  0.50
# |   |   |--- class: 0

# %%
#Decision tree Estimator - Breast Cancer
from id3 import Id3Estimator, export_text

clf = Id3Estimator()
clf.fit(x1_train, y1_train, check_input=True)
y_pred_1 = clf.predict(x1_test)

print("Accuracy:",metrics.accuracy_score(y1_test, y_pred_1))
print("F1:",metrics.f1_score(y1_test, y_pred_1))

#show graph

print(export_text(clf.tree_, x1.columns.values.tolist()))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\LilyRaid\Documents\ML\decision-tree-learning-exploration\.ipynb_checkpoints\model-latest-checkpoint.ipynb Cell 9' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/LilyRaid/Documents/ML/decision-tree-learning-exploration/.ipynb_checkpoints/model-latest-checkpoint.ipynb#ch0000008?line=0'>1</a> #Decision tree Estimator - Breast Cancer
# ----> <a href='vscode-notebook-cell:/c%3A/Users/LilyRaid/Documents/ML/decision-tree-learning-exploration/.ipynb_checkpoints/model-latest-checkpoint.ipynb#ch0000008?line=1'>2</a> from id3 import Id3Estimator, export_text
#       <a href='vscode-notebook-cell:/c%3A/Users/LilyRaid/Documents/ML/decision-tree-learning-exploration/.ipynb_checkpoints/model-latest-checkpoint.ipynb#ch0000008?line=3'>4</a> clf = Id3Estimator()
#       <a href='vscode-notebook-cell:/c%3A/Users/LilyRaid/Documents/ML/decision-tree-learning-exploration/.ipynb_checkpoints/model-latest-checkpoint.ipynb#ch0000008?line=4'>5</a> clf.fit(x1_train, y1_train, check_input=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\id3\__init__.py:3, in <module>
#       <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/__init__.py?line=0'>1</a> from .id3 import Id3Estimator
#       <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/__init__.py?line=1'>2</a> from . import id3
# ----> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/__init__.py?line=2'>3</a> from .export import export_graphviz
#       <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/__init__.py?line=3'>4</a> from .export import export_text
#       <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/__init__.py?line=5'>6</a> __all__ = ['Id3Estimator', 'export_graphviz', 'export_text']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\id3\export.py:1, in <module>
# ----> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/export.py?line=0'>1</a> from sklearn.externals import six
#       <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/export.py?line=1'>2</a> from .splitter import SplitRecord, CalcRecord
#       <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/export.py?line=2'>3</a> import numpy as np
#
# ImportError: cannot import name 'six' from 'sklearn.externals' (C:\Users\LilyRaid\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\externals\__init__.py)

# %%
#Decision tree Estimator - Play Tennis
from id3 import Id3Estimator

clf = Id3Estimator()
clf.fit(x2_train, y2_train, check_input=True)
y_pred_2 = clf.predict(x2_test)

print("Accuracy:",metrics.accuracy_score(y2_test, y_pred_2))
print("F1:",metrics.f1_score(y2_test, y_pred_2))

#show graph

print(export_text(clf.tree_, x2.columns.values.tolist()))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\LilyRaid\Documents\ML\decision-tree-learning-exploration\.ipynb_checkpoints\model-latest-checkpoint.ipynb Cell 10' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/LilyRaid/Documents/ML/decision-tree-learning-exploration/.ipynb_checkpoints/model-latest-checkpoint.ipynb#ch0000009?line=0'>1</a> #Decision tree Estimator - Play Tennis
# ----> <a href='vscode-notebook-cell:/c%3A/Users/LilyRaid/Documents/ML/decision-tree-learning-exploration/.ipynb_checkpoints/model-latest-checkpoint.ipynb#ch0000009?line=1'>2</a> from id3 import Id3Estimator
#       <a href='vscode-notebook-cell:/c%3A/Users/LilyRaid/Documents/ML/decision-tree-learning-exploration/.ipynb_checkpoints/model-latest-checkpoint.ipynb#ch0000009?line=3'>4</a> clf = Id3Estimator()
#       <a href='vscode-notebook-cell:/c%3A/Users/LilyRaid/Documents/ML/decision-tree-learning-exploration/.ipynb_checkpoints/model-latest-checkpoint.ipynb#ch0000009?line=4'>5</a> clf.fit(x2_train, y2_train, check_input=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\id3\__init__.py:3, in <module>
#       <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/__init__.py?line=0'>1</a> from .id3 import Id3Estimator
#       <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/__init__.py?line=1'>2</a> from . import id3
# ----> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/__init__.py?line=2'>3</a> from .export import export_graphviz
#       <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/__init__.py?line=3'>4</a> from .export import export_text
#       <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/__init__.py?line=5'>6</a> __all__ = ['Id3Estimator', 'export_graphviz', 'export_text']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\id3\export.py:1, in <module>
# ----> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/export.py?line=0'>1</a> from sklearn.externals import six
#       <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/export.py?line=1'>2</a> from .splitter import SplitRecord, CalcRecord
#       <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/id3/export.py?line=2'>3</a> import numpy as np
#
# ImportError: cannot import name 'six' from 'sklearn.externals' (C:\Users\LilyRaid\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\externals\__init__.py)

# %%
#Network Algorithm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split


clf = MLPClassifier(random_state=1,max_iter=1000).fit(x2_train,y2_train)
clf.predict_proba(x2_train)
npredict = clf.predict(x2_test)
print("Accuracy:",metrics.accuracy_score(y2_test, npredict))
print("F1:",metrics.f1_score(y2_test, npredict))
# Out:
# Accuracy: 0.3333333333333333
# F1: 0.5

# %%
# Logistixc Regression Breast Cancer
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(random_state=0, solver='lbfgs', max_iter=10000).fit(x1_train, y1_train)
y_pred_1 = clf.predict(x1_test)
print("Accuracy:",metrics.accuracy_score(y1_test, y_pred_1))
print("F1:",metrics.f1_score(y1_test, y_pred_1))
# Out:
# Accuracy: 0.9298245614035088
# F1: 0.95

# %%
# Logistixc Regression Play Tennis

clf = LogisticRegression(random_state=0, solver='lbfgs', max_iter=3000).fit(x2_train, y2_train)
y_pred_2 = clf.predict(x2_test)
print("Accuracy:",metrics.accuracy_score(y2_test, y_pred_2))
print("F1:",metrics.f1_score(y2_test, y_pred_2))
# Out:
# Accuracy: 0.3333333333333333
# F1: 0.5

# %%
#K Means
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

kmeans = KMeans(2)
kmeans.fit_predict(x2_train,y2_train)
kpredict = kmeans.predict(x2_test)
print("Accuracy:",metrics.accuracy_score(y2_test, kpredict))
print("F1:",metrics.f1_score(y2_test, kpredict))
# Out:
# Accuracy: 1.0
# F1: 1.0

# %%
#SVC
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(x2_train,y2_train)
spredict = clf.predict(x2_test)
print("Accuracy:",metrics.accuracy_score(y2_test, spredict))
print("F1:",metrics.f1_score(y2_test, kpredict))
# Out:
# Accuracy: 0.6666666666666666
# F1: 1.0
